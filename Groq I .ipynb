# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadIrtiza17/AI-WORKSHOP-TRAINING/blob/main/Groq%20I%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 5.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
my_api_key=userdata.get('my_first')

# %%
import os

from groq import Groq
from IPython.display import display, Markdown

client = Groq(
    api_key= my_api_key,
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama-3.3-70b-versatile",
)

display(Markdown(chat_completion.choices[0].message.content))
# Out:
# Fast language models are crucial in natural language processing (NLP) and have numerous applications in various fields. The importance of fast language models can be understood from the following aspects:
#
# 1. **Real-time Applications**: Fast language models enable real-time applications such as chatbots, virtual assistants, and language translation systems. These models can quickly process and respond to user input, providing an efficient and seamless user experience.
# 2. **Efficient Processing**: Fast language models can process large amounts of text data quickly, making them ideal for applications that require speedy data analysis, such as text classification, sentiment analysis, and entity recognition.
# 3. **Low Latency**: Fast language models reduce latency, which is critical in applications where response time is essential, such as in customer service chatbots, voice assistants, or language translation systems.
# ...

# %%
user_input = input("Enter your prompt: ")

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": user_input,
        }
    ],
    model="llama-3.3-70b-versatile",
)

display(Markdown(chat_completion.choices[0].message.content))
# Out:
# Enter your prompt: tell me about IOBM karchi
# IOBM (Institute of Business Management) Karachi is a well-known educational institution in Pakistan, particularly in the field of business and management studies. Here's an overview:
#
# **History and Background:**
# Established in 1995, IOBM is a private research university located in Karachi, Sindh, Pakistan. The institute is recognized by the Higher Education Commission (HEC) of Pakistan and is accredited by the National Accreditation Council for Teachers Education (NACTE).
#
# **Academic Programs:**
# IOBM offers a wide range of undergraduate, graduate, and postgraduate programs in various fields, including:
#
# 1. Business Administration
# 2. Computer Science
# 3. Economics
# 4. Engineering
# 5. Management Sciences
# 6. Social Sciences
# 7. Media Sciences
#
# **Research and Publications:**
# ...
